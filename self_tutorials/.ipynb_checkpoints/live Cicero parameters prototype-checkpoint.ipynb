# %%
import time
import pandas as pd
import asyncio
import ipysheet
from datetime import datetime
import numpy as np
from breadboard import *
import json
bc = BreadboardClient(config_path='API_CONFIG_fermi1.json')
# sheet = ipysheet.sheet(rows = 10,columns = 10)
# with ipysheet.hold_cells():
#     default_columns = ['runtime','bad shot', 'notes']
#     for i in range(10):
#         for j in range(10):
#             if j == 1:
#                 ipysheet.cell(i,j,False)
#             elif j == 2:
#                 ipysheet.cell(i,j,'')
#             else:
#                 ipysheet.cell(i,j,None)
#     for i in range(len(default_columns)):        
#         ipysheet.cell(0,i,default_columns[i])

# %%
# stop_widget = widgets.ToggleButton(
#     value=False,
#     description='stop updates',
#     disabled=False,
#     button_style='warning', # 'success', , 'stop updates', 'danger' or ''
#     # (FontAwesome names without the `fa-` prefix)
# )
# display(stop_widget)

async def update_sheet(new_row = None):
    if new_row is None:
        pass
    n_rows = 10
    for n in range(n_rows):
        if sheet[n,0].value is None:
            print(n)
            break #sets n as row index for earliest blank row
    sheet[n,0].value = new_row['runtime']

async def fetch_newest_snippet():
    response = bc._send_message('get','/runs/', params = {'lab':'fermi1'}).json()
    snippet = response['results'][-1]
#     runtime = response['results'][-1]['runtime']
#     runtime = datetime.strptime(runtime.replace('T','-').replace('Z',''), "%Y-%m-%d-%H:%M:%S")
    time.sleep(2)
    return snippet

async def main():
    fetch_task = asyncio.create_task(fetch_newest_snippet())
    await fetch_task
    new_row = {'runtime':fetch_task.result()['runtime']}
    while True: #need a widget that gracefully stops and saves sheet
        update_sheet_task = asyncio.create_task(update_sheet(new_row))
        fetch_task = asyncio.create_task(fetch_newest_snippet())
        await update_sheet_task
        await fetch_task
        new_runtime = fetch_task.result()['runtime']
        new_row = {'runtime':new_runtime}
        
await main()

    
    #########################
    #watch for new files here
    #https://pythonhosted.org/watchdog/quickstart.html
    
#     analysis = 'text from file'
    
#     if analysis not in expt_df.keys():
#         expt_df[analysis] = None
    
#     expt_df.loc[expt_df.index.max(), analysis] = analysis_value
    
    #########################
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# cell_name in async-def-wrapper()
#
# cell_name in main()
#
# CancelledError:

# %%
display(sheet)
# Out:
# Sheet(cells=(Cell(column_end=0, column_start=0, row_end=0, row_start=0, type='text', value='runtime'), Cell(co…

# %%
import ipywidgets as widgets

stop_widget = widgets.ToggleButton(
    value=False,
    description='stop updates',
    disabled=False,
    button_style='warning', # 'success', , 'stop updates', 'danger' or ''
    # (FontAwesome names without the `fa-` prefix)
)
stop_widget
# Out:
# ToggleButton(value=False, button_style='warning', description='stop updates')

# %%
sheet[1,1].value
# Out:
# False

# %%
stop_widget.value
# Out:
# True

# %%
df = qgrid_widget.get_changed_df()
display(df)
df = df.append(new_row_dict, ignore_index = True)
display(df)
qgrid_widget.close()
qgrid.show_grid(df)
# Out:
#    runtime  badShot notes  dummy1
# 0        0    False  blah    -0.1
# 1        1    False          -0.1
# 2        2    False          -0.1
# 3        3    False          -0.1
# 4        4    False          -0.1
#    runtime  badShot notes  dummy1
# 0        0    False  blah    -0.1
# 1        1    False          -0.1
# 2        2    False          -0.1
# 3        3    False          -0.1
# 4        4    False          -0.1
# 5        5    False          -0.1
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
expt_df["new"] = None
expt_df.loc[0,'new'] = 42
expt_df
# Out:
#    runtime  dummy1  badShot BUG notes BUG   new
# 0        0    -0.1        False              42
# 1        1    -0.1        False            None
# 2        2    -0.1        False            None
# 3        3    -0.1        False            None
# 4        4    -0.1        False            None
# 5        5    -0.1        False            None
# 6        6    -0.1        False            None
# 7        7    -0.1        False            None
# 8        8    -0.1        False            None
# 9        9    -0.1        False            None

# %%
'dummy2' not in expt_df.keys()
# Out:
# True

# %%
qgrid_widget.add_row([('runtime',1),('dummy1',1)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a53fcdc36338> in <module>
# ----> 1 qgrid_widget.add_row([('runtime',1),('dummy1',1)])
#
# ~\Anaconda3\lib\site-packages\qgrid\grid.py in add_row(self, row)
#    1617             added_index = self._duplicate_last_row()
#    1618         else:
# -> 1619             added_index = self._add_row(row)
#    1620
#    1621         self._notify_listeners({
#
# ~\Anaconda3\lib\site-packages\qgrid\grid.py in _add_row(self, row)
#    1663         col_names = list(col_names)
#    1664         col_data = list(col_data)
# -> 1665         index_col_val = dict(row)[df.index.name]
#    1666
#    1667         # check that the given column names match what
#
# KeyError: None

# %%
def update_run(bc, run_id, params):
    if isinstance(run_id, float):
        run_id = int(run_id)
    response = bc._send_message('get','/runs/' + str(run_id) + '/').json()
    response.update(params)
    new_response = bc._send_message('put','/runs/' + str(run_id) + '/', data = json.dumps(response))
    if new_response.status_code == 200:
        print('updated run ' + str(run_id) + ' successfully')
    else:
        print('error: updating run' + str(run_id) + ' failed')
        
params  = {'notes': {'labbook':'alex was here','bad shot': False}}
update_run(bc, 191372, params)
response = bc._send_message('get','/runs/191372/').json()
response
# Out:
# error: updating run191372 failed
# {'url': 'https://breadboard-215702.appspot.com/runs/191372/',
#  'id': 191372,
#  'created': '2020-02-21T19:24:20.388281Z',
#  'runtime': '2020-02-21T14:24:13Z',
#  'parameters': {'TOF': 0.01,
#   'NaTOF': 1.0,
#   'nOsci': 10.0,
#   'ZCamNa': 19.0,
#   'dummy1': 41.0,
#   'dummy2': 91.0,
#   'dummy3': 0.041,
#   'K40MOTF': 7.35,
#   'MOTFreq': 5.5,
#   'Magtrap': 1.0,
#   'SeqMode': 0.0,
#   'CMOTFreq': 5.1,
#   'CompTime': 30.0,
#   'FBspConv': 2.3502470000000004,
#   'FBinGauss': 85.7,
#   'K40MOTReF': 5.45,
#   'K40MOTReP': 2.4,
#   'Kloading1': 6.0,
#   'NaLoading': 3.0,
#   'K40loading': 5.0,
#   'Li MOT Pow': 2.8,
#   'Naloading1': 4.0,
#   'SGendpoint': 2.5,
#   'TandemFreq': 202.0,
#   'TandemVolt': 5.85746124704,
#   'drivingAmp': 0.01,
#   'CRepumpFreq': 5.5,
#   'IPGEndpoint': 1.7,
#   'ImagTanFreq': 259.653,
#   'Li CMOT Pow': 2.0,
#   'Li ImagFreq': 7.9,
#   'NaF2Voltage': 0.3140000000000003,
#   'ODTendvalue': 0.3,
#   'PumpTanFreq': 250.0,
#   'PumpTanVolt': 7.678100000000001,
#   'TOFminus1ms': -0.99,
#   'drivingFreq': 41.0,
#   'CRepumpPower': 3.6,
#   'IterationNum': 40.0,
#   'K41 CMOTFreq': 7.05,
#   'K41 MOTFreqV': 0.0,
#   'NaTandemVolt': 5.08054,
#   'FBPowerSupply': 3.0,
#   'ImgTanVoltm72': 7.404470999999999,
#   'K40ImgMOTFreq': 7.15,
#   'K40MolassrepP': 2.5,
#   'K40PumpReFreq': 5.55,
#   'K41 PumpRePow': 4.0,
#   'K41 RepumpPow': 2.5,
#   'Li MolMOT Pow': 2.0,
#   'MOTRepumpFreq': 6.15,
#   'NaLoading1old': 0.0,
#   'drivingAmpIPG': 0.2,
#   'FBPowerSupply2': 3.4605795,
#   'ImagTandemVolt': 7.583426,
#   'IterationCount': 112.0,
#   'K40 AmplifierP': 5.5,
#   'K40PumpMOTFreq': 7.3,
#   'K40PumpRePower': 3.7,
#   'K41 CRepumpPow': 2.6,
#   'K41 PumpReFreq': 1.55,
#   'Li CRepump Pow': 2.0,
#   'Li Repump  Pow': 2.8,
#   'PumpRepumpFreq': 5.8,
#   'K41 CRepumpFreq': 1.65,
#   'K41 PumpMOTFreq': 6.1,
#   'Li CLockin Freq': 4.9,
#   'Li CRepump Freq': 5.9,
#   'drivingDuration': 243.9,
#   'Li MolRepump Pow': 1.5,
#   'SequenceDuration': 0.101,
#   'SequenceModeName': 'New Zcam',
#   'TiSaAlignPreTrig': 0.0,
#   'analysisPhaseDeg': 0.0,
#   'K40PumpSlowerAOMP': 0.3,
#   'Li MolLockin Freq': 4.1,
#   'Li MolRepump Freq': 5.7,
#   'analysisPhaseTime': 0.0,
#   'Li MOT Lockin Freq': 4.9,
#   'Li MOT Repump Freq': 5.9,
#   'ListBoundVariables': ['dummy1', 'drivingFreq'],
#   'Zcam KTOF position': 21.9999914},
#  'notes': 'alex was here',
#  'workday': '2020-02-21',
#  'lab': 2,
#  'dataset': None,
#  'images': []}

# %%
json.dumps(params)
# Out:
# '{"notes": {"labbook": "alex was here", "bad shot": false}}'

# %%
bc.get_runs().json()['results'][0]
# Out:
# {'url': 'https://breadboard-215702.appspot.com/runs/209461/',
#  'id': 209461,
#  'created': '2020-07-22T14:19:24.720707Z',
#  'runtime': '2020-07-22T10:19:10Z',
#  'parameters': {'Bx': 0.45,
#   'By': 0.0,
#   'Bz': 0.0,
#   'Bz2': 0.1,
#   'TOF': 15.0,
#   'MOTReP': 2.65,
#   'dummy1': -0.1,
#   'dummy2': 0.014285714285714287,
#   'dummy3': -0.0014285714285714288,
#   'K40MOTF': 7.35,
#   'MOTFreq': 5.5,
#   'Magtrap': 1.0,
#   'SeqMode': 0.0,
#   'CMOTFreq': 5.1,
#   'CompTime': 10.0,
#   'EVC time': 2.6,
#   'MOT coil': 0.5,
#   'MOTPower': 5.0,
#   'DummyTime': 0.0,
#   'FBpidVset': 1.0,
#   'K40MOTReF': 5.45,
#   'K40MOTReP': 2.4,
#   'FB current': 1.65,
#   'FBpidVset2': 4.0,
#   'FinalKinfe': 0.0,
#   'K41MOTFreq': 85.5,
#   'Li MOT Pow': 2.8,
#   'MolMOTFreq': 5.2,
#   'MolRepFreq': 5.55,
#   'MolTAPower': 1.3,
#   'ODT1 Power': 0.45,
#   'TandemFreq': 202.0,
#   'TandemVolt': 5.85746124704,
#   'CRepumpFreq': 5.5,
#   'Decomp0Time': 0.5,
#   'ImagTanFreq': 247.0,
#   'K39TanPower': 2.5,
#   'Li CMOT Pow': 2.0,
#   'Li ImagFreq': 7.9,
#   'MolRepPower': 2.1,
#   'PumpMOTFreq': 6.54,
#   'PumpTanFreq': 251.0,
#   'PumpTanVolt': 7.70532,
#   'CRepumpPower': 3.6,
#   'IterationNum': 0.0,
#   'K41 CMOTFreq': 7.05,
#   'K41 MOTFreqV': 6.036419411479372,
#   'FBPowerSupply': 1.242633,
#   'K39ImgMOTFreq': 6.0,
#   'K40ImgMOTFreq': 7.15,
#   'K40MolassrepP': 2.5,
#   'K40PumpReFreq': 5.55,
#   'K41 PumpRePow': 4.0,
#   'K41 RepumpPow': 2.5,
#   'K41RepumpFreq': 214.0,
#   'Li MolMOT Pow': 2.0,
#   'MOTRepumpFreq': 6.15,
#   'FBPowerSupply2': 3.4605795000000006,
#   'ImagTandemVolt': 7.59644,
#   'IterationCount': 8.0,
#   'K40 AmplifierP': 5.5,
#   'K40PumpMOTFreq': 7.3,
#   'K40PumpRePower': 3.7,
#   'K41 CRepumpPow': 2.6,
#   'K41 ImgMOTFreq': 6.0,
#   'K41 MolMOTFreq': 7.657,
#   'K41 PumpReFreq': 1.55,
#   'Li CRepump Pow': 2.0,
#   'Li Repump  Pow': 2.8,
#   'PumpRepumpFreq': 5.8,
#   'K39PumpTanPower': 0.7,
#   'K41 CRepumpFreq': 1.65,
#   'K41 PumpMOTFreq': 6.1,
#   'K41 RepumpFreqV': 2.1011856703999854,
#   'Li CLockin Freq': 4.9,
#   'Li CRepump Freq': 5.9,
#   'PumpRepumpPower': 3.6,
#   'K41 MolRepumpPow': 2.7,
#   'K41SlowerMOTFreq': 90.0,
#   'Li MolRepump Pow': 1.5,
#   'SequenceDuration': 17.43356,
#   'SequenceModeName': 'BECMode',
#   'k39 loading time': 0.0,
#   'K39PumpSlowerAOMP': 2.5,
#   'K40PumpSlowerAOMP': 0.3,
#   'K41 MolRepumpFreq': 2.37,
#   'K41PumpSlowerAOMP': 2.1,
#   'K41SlowerMOTFreqV': 7.227510781250002,
#   'Li MolLockin Freq': 4.1,
#   'Li MolRepump Freq': 5.7,
#   'Li MOT Lockin Freq': 4.9,
#   'Li MOT Repump Freq': 5.9,
#   'ListBoundVariables': ['dummy1'],
#   'K41SlowerRepumpFreq': 105.0,
#   'K41SlowerRepumpFreqV': 8.781177036800003},
#  'notes': '',
#  'workday': '2020-07-22',
#  'dataset': None}

# %%
response = bc._send_message('get','/runs/191372/').json()
response['notes'] = 'TEST NOTE HERE'
updated_dict = response
response1 = bc._send_message('put','/runs/191372/', data = json.dumps(updated_dict))
# response = bc._send_message('get','/runs/191372/').json()
display(response1)
# response = bc._send_message('get','/runs/191372').json()
# response
# Out:
# <Response [200]>

# %%
df = bc.get_runs_df()
df
# Out:
#                   runtime             x   dummy1  TiSa piezo  drivingFreq  \
# 0    2020-02-20T17:21:51Z  1.582219e+09  -0.1000         NaN          NaN
# 1    2020-02-20T17:22:10Z  1.582219e+09  -0.1000         NaN          NaN
# 2    2020-02-20T17:22:29Z  1.582219e+09  -0.2000         NaN          NaN
# 3    2020-02-20T17:22:47Z  1.582219e+09  -0.2000         NaN          NaN
# 4    2020-02-20T17:23:06Z  1.582219e+09  -0.3000         NaN          NaN
# 5    2020-02-20T17:23:25Z  1.582219e+09  -0.3000         NaN          NaN
# 6    2020-02-20T17:24:06Z  1.582219e+09   4.0000         NaN       4.0000
# 7    2020-02-20T17:24:36Z  1.582219e+09   4.0000         NaN       4.0000
# 8    2020-02-20T17:25:16Z  1.582220e+09   4.0000         NaN       4.0000
# 9    2020-02-20T17:25:48Z  1.582220e+09   4.0000         NaN       4.0000
# 10   2020-02-20T17:26:11Z  1.582220e+09   4.0000         NaN       4.0000
# 11   2020-02-20T17:26:34Z  1.582220e+09   4.0000         NaN       4.0000
# 12   2020-02-20T17:28:21Z  1.582220e+09   7.5825         NaN       7.5825
# 13   2020-02-20T17:28:57Z  1.582220e+09   7.5825         NaN       7.5825
# 14   2020-02-20T17:32:21Z  1.582220e+09   7.5825         NaN       7.5825
# 15   2020-02-20T17:33:10Z  1.582220e+09   7.5825         NaN       7.5825
# 16   2020-02-20T17:34:32Z  1.582220e+09   7.5825         NaN       7.5825
# 17   2020-02-20T17:35:31Z  1.582220e+09   7.5825         NaN       7.5825
# 18   2020-02-20T17:36:21Z  1.582220e+09   7.5825         NaN       7.5825
# 19   2020-02-20T17:37:21Z  1.582220e+09   7.5825         NaN       7.5825
# 20   2020-02-20T17:37:55Z  1.582220e+09   7.5825         NaN       7.5825
# 21   2020-02-20T17:38:36Z  1.582220e+09   7.5825         NaN       7.5825
# 22   2020-02-20T17:39:09Z  1.582220e+09   7.5825         NaN       7.5825
# 23   2020-02-20T18:26:30Z  1.582223e+09   7.5825         NaN       7.5825
# 24   2020-02-20T18:27:07Z  1.582223e+09   7.5825         NaN       7.5825
# 25   2020-02-20T18:29:42Z  1.582223e+09   7.5825         NaN       7.5825
# 26   2020-02-20T18:30:48Z  1.582223e+09   7.5825         NaN       7.5825
# 27   2020-02-20T18:31:34Z  1.582223e+09   7.5825         NaN       7.5825
# 28   2020-02-20T18:32:21Z  1.582224e+09   7.5825         NaN       7.5825
# 16   1.582220e+09
# 17   1.582220e+09
# 18   1.582220e+09
# 19   1.582220e+09
# 20   1.582220e+09
# 21   1.582220e+09
# 22   1.582220e+09
# 23   1.582223e+09
# 24   1.582223e+09
# 25   1.582223e+09
# 26   1.582223e+09
# 27   1.582223e+09
# 28   1.582224e+09
# 29   1.582224e+09
# ..            ...
# 170  1.582295e+09
# 171  1.582295e+09
# 172  1.582295e+09
# 173  1.582295e+09
# 174  1.582295e+09
# 175  1.582295e+09
# 176  1.582295e+09
# 177  1.582295e+09
# 178  1.582295e+09
# 179  1.582295e+09
# 180  1.582295e+09
# 181  1.582295e+09
# 182  1.582295e+09
# 183  1.582295e+09
# 184  1.582295e+09
# 185  1.582295e+09
# 186  1.582295e+09
# 187  1.582295e+09
# 188  1.582295e+09
# 189  1.582295e+09
# 190  1.582295e+09
# 191  1.582295e+09
# 192  1.582295e+09
# 193  1.582295e+09
# 194  1.582295e+09
# 195  1.582295e+09
# 196  1.582295e+09
# 197  1.582295e+09
# 198  1.582295e+09
# 199  1.582295e+09
#
# [200 rows x 6 columns]

# %%
display(updated_dict['notes'])
response1.json()
# Out:
# 'TEST NOTE HERE'
# {'url': 'https://breadboard-215702.appspot.com/runs/191372/',
#  'id': 191372,
#  'created': '2020-02-21T19:24:20.388281Z',
#  'runtime': '2020-02-21T14:24:13Z',
#  'parameters': {'TOF': 0.01,
#   'NaTOF': 1.0,
#   'nOsci': 10.0,
#   'ZCamNa': 19.0,
#   'dummy1': 41.0,
#   'dummy2': 91.0,
#   'dummy3': 0.041,
#   'K40MOTF': 7.35,
#   'MOTFreq': 5.5,
#   'Magtrap': 1.0,
#   'SeqMode': 0.0,
#   'CMOTFreq': 5.1,
#   'CompTime': 30.0,
#   'FBspConv': 2.3502470000000004,
#   'FBinGauss': 85.7,
#   'K40MOTReF': 5.45,
#   'K40MOTReP': 2.4,
#   'Kloading1': 6.0,
#   'NaLoading': 3.0,
#   'K40loading': 5.0,
#   'Li MOT Pow': 2.8,
#   'Naloading1': 4.0,
#   'SGendpoint': 2.5,
#   'TandemFreq': 202.0,
#   'TandemVolt': 5.85746124704,
#   'drivingAmp': 0.01,
#   'CRepumpFreq': 5.5,
#   'IPGEndpoint': 1.7,
#   'ImagTanFreq': 259.653,
#   'Li CMOT Pow': 2.0,
#   'Li ImagFreq': 7.9,
#   'NaF2Voltage': 0.3140000000000003,
#   'ODTendvalue': 0.3,
#   'PumpTanFreq': 250.0,
#   'PumpTanVolt': 7.678100000000001,
#   'TOFminus1ms': -0.99,
#   'drivingFreq': 41.0,
#   'CRepumpPower': 3.6,
#   'IterationNum': 40.0,
#   'K41 CMOTFreq': 7.05,
#   'K41 MOTFreqV': 0.0,
#   'NaTandemVolt': 5.08054,
#   'FBPowerSupply': 3.0,
#   'ImgTanVoltm72': 7.404470999999999,
#   'K40ImgMOTFreq': 7.15,
#   'K40MolassrepP': 2.5,
#   'K40PumpReFreq': 5.55,
#   'K41 PumpRePow': 4.0,
#   'K41 RepumpPow': 2.5,
#   'Li MolMOT Pow': 2.0,
#   'MOTRepumpFreq': 6.15,
#   'NaLoading1old': 0.0,
#   'drivingAmpIPG': 0.2,
#   'FBPowerSupply2': 3.4605795,
#   'ImagTandemVolt': 7.583426,
#   'IterationCount': 112.0,
#   'K40 AmplifierP': 5.5,
#   'K40PumpMOTFreq': 7.3,
#   'K40PumpRePower': 3.7,
#   'K41 CRepumpPow': 2.6,
#   'K41 PumpReFreq': 1.55,
#   'Li CRepump Pow': 2.0,
#   'Li Repump  Pow': 2.8,
#   'PumpRepumpFreq': 5.8,
#   'K41 CRepumpFreq': 1.65,
#   'K41 PumpMOTFreq': 6.1,
#   'Li CLockin Freq': 4.9,
#   'Li CRepump Freq': 5.9,
#   'drivingDuration': 243.9,
#   'Li MolRepump Pow': 1.5,
#   'SequenceDuration': 0.101,
#   'SequenceModeName': 'New Zcam',
#   'TiSaAlignPreTrig': 0.0,
#   'analysisPhaseDeg': 0.0,
#   'K40PumpSlowerAOMP': 0.3,
#   'Li MolLockin Freq': 4.1,
#   'Li MolRepump Freq': 5.7,
#   'analysisPhaseTime': 0.0,
#   'Li MOT Lockin Freq': 4.9,
#   'Li MOT Repump Freq': 5.9,
#   'ListBoundVariables': ['dummy1', 'drivingFreq'],
#   'Zcam KTOF position': 21.9999914},
#  'notes': 'TEST NOTE HERE',
#  'workday': '2020-02-21',
#  'lab': 2,
#  'dataset': None,
#  'images': []}

# %%
test = {1:2}
test
# Out:
# {1: 2}

# %%
test.update({3:4})
test
# Out:
# {1: 2, 3: 4}

# %%
response = bc._send_message('get','/images/').json()
response
# Out:
# {'count': 123880,
#  'next': 'https://breadboard-215702.appspot.com/images/?limit=200&offset=200',
#  'previous': None,
#  'results': [{'url': 'https://breadboard-215702.appspot.com/images/59496/',
#    'id': 59496,
#    'name': '2029-02-27_20-28-25_SensicamQE',
#    'created': '2029-02-27T20:28:25Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': None,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123874/',
#    'id': 123874,
#    'name': '2020-07-10_20-32-17_iXon',
#    'created': '2020-07-10T20:32:17Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209440,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123875/',
#    'id': 123875,
#    'name': '2020-07-10_20-31-36_iXon',
#    'created': '2020-07-10T20:31:36Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209439,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123876/',
#    'id': 123876,
#    'name': '2020-07-10_20-30-54_iXon',
#    'created': '2020-07-10T20:30:54Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209438,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123877/',
#    'id': 123877,
#    'name': '2020-07-10_20-30-13_iXon',
#    'created': '2020-07-10T20:30:13Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209437,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123878/',
#    'id': 123878,
#    'name': '2020-07-10_20-29-31_iXon',
#    'created': '2020-07-10T20:29:31Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209436,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123879/',
#    'id': 123879,
#    'name': '2020-07-10_20-28-50_iXon',
#    'created': '2020-07-10T20:28:50Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209435,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123880/',
#    'id': 123880,
#    'name': '2020-07-10_20-28-08_iXon',
#    'created': '2020-07-10T20:28:08Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209434,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123881/',
#    'id': 123881,
#    'name': '2020-07-10_20-27-27_iXon',
#    'created': '2020-07-10T20:27:27Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209433,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/

#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123729/',
#    'id': 123729,
#    'name': '2020-07-10_17-10-30_iXon',
#    'created': '2020-07-10T17:10:30Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209242,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123730/',
#    'id': 123730,
#    'name': '2020-07-10_17-09-49_iXon',
#    'created': '2020-07-10T17:09:49Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209241,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123731/',
#    'id': 123731,
#    'name': '2020-07-10_17-09-07_iXon',
#    'created': '2020-07-10T17:09:07Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209240,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123732/',
#    'id': 123732,
#    'name': '2020-07-10_17-08-26_iXon',
#    'created': '2020-07-10T17:08:26Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209239,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123733/',
#    'id': 123733,
#    'name': '2020-07-10_17-07-45_iXon',
#    'created': '2020-07-10T17:07:45Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209238,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123734/',
#    'id': 123734,
#    'name': '2020-07-10_17-07-03_iXon',
#    'created': '2020-07-10T17:07:03Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209237,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123735/',
#    'id': 123735,
#    'name': '2020-07-10_17-06-22_iXon',
#    'created': '2020-07-10T17:06:22Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209236,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123690/',
#    'id': 123690,
#    'name': '2020-07-10_17-05-41_iXon',
#    'created': '2020-07-10T17:05:41Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209235,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123691/',
#    'id': 123691,
#    'name': '2020-07-10_17-05-00_iXon',
#    'created': '2020-07-10T17:05:00Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209234,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123692/',
#    'id': 123692,
#    'name': '2020-07-10_17-04-18_iXon',
#    'created': '2020-07-10T17:04:18Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209233,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123693/',
#    'id': 123693,
#    'name': '2020-07-10_17-03-37_iXon',
#    'created': '2020-07-10T17:03:37Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209232,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123694/',
#    'id': 123694,
#    'name': '2020-07-10_17-02-56_iXon',
#    'created': '2020-07-10T17:02:56Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209231,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123695/',
#    'id': 123695,
#    'name': '2020-07-10_17-02-14_iXon',
#    'created': '2020-07-10T17:02:14Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209230,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123696/',
#    'id': 123696,
#    'name': '2020-07-10_17-01-33_iXon',
#    'created': '2020-07-10T17:01:33Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209229,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123697/',
#    'id': 123697,
#    'name': '2020-07-10_17-00-51_iXon',
#    'created': '2020-07-10T17:00:51Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209228,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123698/',
#    'id': 123698,
#    'name': '2020-07-10_17-00-10_iXon',
#    'created': '2020-07-10T17:00:10Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209227,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123699/',
#    'id': 123699,
#    'name': '2020-07-10_16-59-29_iXon',
#    'created': '2020-07-10T16:59:29Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209226,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123700/',
#    'id': 123700,
#    'name': '2020-07-10_16-58-48_iXon',
#    'created': '2020-07-10T16:58:48Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209225,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123701/',
#    'id': 123701,
#    'name': '2020-07-10_16-58-06_iXon',
#    'created': '2020-07-10T16:58:06Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209224,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123702/',
#    'id': 123702,
#    'name': '2020-07-10_16-57-25_iXon',
#    'created': '2020-07-10T16:57:25Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209223,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123703/',
#    'id': 123703,
#    'name': '2020-07-10_16-56-44_iXon',
#    'created': '2020-07-10T16:56:44Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209222,
#    'pixel_size': None,
#    'bad_shot': None},
#   {'url': 'https://breadboard-215702.appspot.com/images/123704/',
#    'id': 123704,
#    'name': '2020-07-10_16-56-02_iXon',
#    'created': '2020-07-10T16:56:02Z',
#    'notes': None,
#    'filepath': None,
#    'tags': None,
#    'cropi': None,
#    'atom': None,
#    'odpath': None,
#    'total_atoms': None,
#    'settings': None,
#    'atomsperpixel': None,
#    'thumbnail': None,
#    'run': 209221,
#    'pixel_size': None,
#    'bad_shot': None}]}

# %%
pd.DataFrame(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-b91c8f064580> in <module>
# ----> 1 pd.DataFrame(response)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7403
#    7404             if have_dicts:
# -> 7405                 raise ValueError('Mixing dicts with non-Series may lead to '
#    7406                                  'ambiguous ordering.')
#    7407
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
bc._send_message('get','/runs/', params = {'id':191372}).json()
# Out:
# {'count': 209437,
#  'next': 'https://breadboard-215702.appspot.com/runs/?id=191372&limit=200&offset=200',
#  'previous': None,
#  'results': [{'url': 'https://breadboard-215702.appspot.com/runs/209454/',
#    'id': 209454,
#    'created': '2020-07-11T00:41:58.686582Z',
#    'runtime': '2020-07-10T20:41:56Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 120.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 60.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 36.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.44457399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209453/',
#    'id': 209453,
#    'created': '2020-07-11T00:41:17.316747Z',
#    'runtime': '2020-07-10T20:41:15Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 127.5,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 63.75,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 35.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.45207399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209452/',
#    'id': 209452,
#    'created': '2020-07-11T00:40:35.809286Z',
#    'runtime': '2020-07-10T20:40:33Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 109.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 54.5,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 34.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.43357399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209451/',
#    'id': 209451,
#    'created': '2020-07-11T00:39:54.435588Z',
#    'runtime': '2020-07-10T20:39:52Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 189.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 94.5,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 33.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.51357399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209450/',
#    'id': 209450,
#    'created': '2020-07-11T00:39:13.452716Z',
#    'runtime': '2020-07-10T20:39:11Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 149.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 74.5,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 32.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.47357399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209449/',
#    'id': 209449,
#    'created': '2020-07-11T00:38:31.909807Z',
#    'runtime': '2020-07-10T20:38:29Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 125.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 62.5,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 31.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.44957399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209448/',
#    'id': 209448,
#    'created': '2020-07-11T00:37:50.624537Z',
#    'runtime': '2020-07-10T20:37:48Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 112.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 56.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 30.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.43657399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209447/',
#    'id': 209447,
#    'created': '2020-07-11T00:37:09.572542Z',
#    'runtime': '2020-07-10T20:37:07Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 122.5,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 61.25,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 29.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.44707399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209446/',
#    'id': 209446,
#    'created': '2020-07-11T00:36:28.232045Z',
#    'runtime': '2020-07-10T20:36:26Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 140.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 70.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 28.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.46457399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209445/',
#    'id': 209445,
#    'created': '2020-07-11T00:35:46.829847Z',
#    'runtime': '2020-07-10T20:35:44Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 116.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 58.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 27.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.44057399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209444/',
#    'id': 209444,
#    'created': '2020-07-11T00:35:05.543885Z',
#    'runtime': '2020-07-10T20:35:03Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 114.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 57.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 26.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.43857399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209443/',
#    'id': 209443,
#    'created': '2020-07-11T00:34:24.233001Z',
#    'runtime': '2020-07-10T20:34:21Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 106.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 53.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 25.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 46.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.43057399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.96,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-11',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209442/',
#    'id': 209442,
#    'created': '2020-07-11T00:33:42.823310Z',
#    'runtime': '2020-07-10T20:33:40Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 104.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
# ...
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-10',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209258/',
#    'id': 209258,
#    'created': '2020-07-10T21:21:34.432686Z',
#    'runtime': '2020-07-10T17:21:32Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 143.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 71.5,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 68.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 161.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.46757399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.8,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-10',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209257/',
#    'id': 209257,
#    'created': '2020-07-10T21:20:53.061429Z',
#    'runtime': '2020-07-10T17:20:51Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 100.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 50.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 67.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 161.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.42457399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.8,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 50.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-10',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209256/',
#    'id': 209256,
#    'created': '2020-07-10T21:20:11.833812Z',
#    'runtime': '2020-07-10T17:20:09Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 146.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 73.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 66.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 161.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.47057399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.8,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-10',
#    'dataset': None},
#   {'url': 'https://breadboard-215702.appspot.com/runs/209255/',
#    'id': 209255,
#    'created': '2020-07-10T21:19:30.471041Z',
#    'runtime': '2020-07-10T17:19:28Z',
#    'parameters': {'pi': 3.14159265359,
#     'TOF': 0.0,
#     'evap1a': 8.0,
#     'evap1b': 3.0,
#     'modAmp': 58.0,
#     'StirEnd': 7.0,
#     'TOPfreq': 15474.5,
#     'cuttime': 0.0,
#     'evap_t1': 10.0,
#     'evap_t2': 10.0,
#     'evap_t3': 6.0,
#     'flyTime': 550.0,
#     'whirrMW': 22.17125,
#     'Img_time': 7.0,
#     'MW power': 7.0,
#     'StirTime': 50.0,
#     'TOPphase': 3.932,
#     'compQuad': 2.0,
#     'evap1mid': 22.5625,
#     'evap2end': 22.5625,
#     'evap3End': 22.17275,
#     'holdTime': 152.0,
#     'modPhase': 300.0,
#     'numSpins': 100.0,
#     'pumptime': 200.0,
#     'spinCool': 22.189375000000002,
#     'trueFreq': 177.25,
#     'whirrAmp': 0.25,
#     'whirrTau': 0.25,
#     'StirStart': 3.0,
#     'TOPendMid': 2.0,
#     'evap1 end': 22.2,
#     'finalQuad': 22.1625,
#     'modLength': 1133.25,
#     'stripQuad': 0.6,
#     'whirrFreq': 4.496,
#     'whirrTime': 0.0,
#     'Na MOT amp': 1.0,
#     'TOPendHold': -2.5,
#     'TOPendLoad': 2.0,
#     'TOPevapMid': 22.25,
#     'TOPsideMid': -1.15,
#     'catch QUAD': 0.5,
#     'decompTime': 0.5,
#     'evap2start': 22.25,
#     'evapEndTOP': 22.21625,
#     'extraPhase': 2.95,
#     'holdSaddle': 0.0,
#     'holdTime/2': 76.0,
#     'vortexCool': 22.174375,
#     'whirrMWMHz': 1773.7,
#     'Decomp QUAD': 0.0,
#     'Li MOT freq': 4.5,
#     'Na F=1 pAmp': 1.0,
#     'Na F=2 iAmp': 0.2,
#     'Na F=2 pAmp': 0.2,
#     'Na MOT freq': 6.3,
#     'TOPevapTime': 5.0,
#     'TOPsideHold': -3.53,
#     'TOPsideLoad': -1.15,
#     'deCompQuad1': 0.6,
#     'deCompQuad2': 0.7,
#     'evap1endMHz': 1776.0,
#     'evap1midMHz': 1805.0,
#     'evap2endMHz': 1805.0,
#     'evap3EndMHz': 1773.82,
#     'evap_bottom': 22.15,
#     'quadTopLoad': 0.4,
#     'reWhirrFreq': 4.3,
#     'reWhirrTime': 7.0,
#     'spinCoolMHz': 1775.15,
#     '4VstirrPhase': 3.846,
#     'IterationNum': 65.0,
#     'MOT gradient': 0.1,
#     'Na F=1 pFreq': 4.75,
#     'Na F=2 iFreq': 2.25,
#     'Na F=2 pFreq': 0.725,
#     'Scell x bias': 0.164,
#     'Scell z bias': 0.75,
#     'TOP rampdown': 0.75,
#     'TOPside2Quad': -3.525,
#     'cleanUpLevel': 0.08,
#     'evapStartTOP': 22.24375,
#     'finalQuadMHz': 1773.0,
#     'freeSpinTime': 4.65,
#     'rampToSaddle': 100.0,
#     'transfer res': 0.25,
#     'Li F=1/2 pAmp': 1.0,
#     'Li F=3/2 iAmp': 0.2,
#     'Li F=3/2 pAmp': 0.15,
#     'TOPevapMidMHz': 1780.0,
#     'ellipseRelAmp': 4.82,
#     'evap2startMHz': 1780.0,
#     'evapBottomMHz': 1772.0,
#     'evapEndTOPMHz': 1777.3,
#     'reTrigTOPTime': 18.0,
#     'transfer time': 1.5,
#     'vortexCoolMHz': 1773.95,
#     'whirrRampTime': 10.0,
#     'F=2 iAmp SCell': 0.29,
#     'IterationCount': 161.0,
#     'Li F=1/2 pFreq': 4.5,
#     'Li F=3/2 iFreq': 5.826,
#     'Li F=3/2 pFreq': 6.5,
#     'Li repump freq': 4.2,
#     'Na repump freq': 7.5,
#     'TOPside2p5Quad': -3.5,
#     'ellipsifierAmp': 0.111,
#     'holdTimeFriend': 315.0,
#     'totalWhirrTime': 1.5,
#     'Li 3/2 Cell imA': 0.12,
#     'Li 3/2 Cell imF': 4.5,
#     'ellipseStirTime': 2000.0,
#     'evapStartTOPMHz': 1779.5,
#     'initial MW freq': 23.95,
#     '2VQuadstirrPhase': 3.81,
#     'Initial MW power': 7.0,
#     'SCell iFeshbach ': 0.015,
#     'SequenceDuration': 39.47657399999999,
#     'SequenceModeName': 'bec',
#     'TOPphaseSpinning': 3.8,
#     'elliptifierPhase': 45.0,
#     'intermediateTime': 200.0,
#     'dynamicEvapLength': 2.7,
#     'quadPostTransport': 0.7491,
#     'staticEllipseFreq': 0.2,
#     'sunshineDelayTime': 1128.6,
#     'ListBoundVariables': ['holdTime',
#      'whirrFreq',
#      'TOPphase',
#      'stripQuad',
#      'extraPhase',
#      'trueFreq',
#      'TOPphaseSpinning',
#      'ellipseAmpSpinning',
#      'holdSaddle'],
#     'Na F=2 iFreq SCell': 2.55,
#     'ellipseAmpSpinning': 8.246,
#     'transfer MOT start': 1.067,
#     'accordionHoldSpacing': 4.4,
#     'accordionLoadSpacing': 4.1,
#     'ellipsifierFreqRampTime': 1.0},
#    'notes': '',
#    'workday': '2020-07-10',
#    'dataset': None}]}
